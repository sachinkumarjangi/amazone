# %% [markdown]
# <a href="https://colab.research.google.com/github/sachinkumarjangi/blink-it/blob/main/amazone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/amazon.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df=df.drop(['about_product'],axis=1)
print(df)
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
total_actual_price=df['actual_price'].sum()
print(total_actual_price)
# Out:
# ₹1,099₹349₹1,899₹699₹399₹1,000₹499₹299₹999₹299₹339₹799₹700₹899₹399₹399₹24,999₹399₹499₹21,990₹1,799₹499₹22,900₹199₹19,990₹699₹19,999₹399₹1,999₹999₹750₹499₹1,099₹599₹999₹666.66₹1,900₹999₹45,999₹1,999₹695₹34,999₹1,099₹1,599₹199₹999₹1,208₹475₹999₹395₹2,199₹500₹2,100₹12,999₹349₹499₹1,399₹21,999₹1,499₹349₹799₹47,900₹999₹845₹24,999₹1,400₹699₹14,990₹2,999₹700₹899₹599₹42,999₹499₹999₹499₹399₹30,990₹499₹3,999₹1,099₹249₹19,125₹799₹1,299₹39,999₹40,990₹52,900₹999₹1,999₹800₹31,999₹699₹999₹40,990₹349₹799₹999₹1,899₹1,499₹1,499₹1,809₹899₹29,999₹999₹999₹1,299₹999₹65,000₹800₹20,000₹999₹23,990₹999₹1,999₹399₹1,999₹999₹999₹899₹1,999₹3,999₹15,999₹44,990₹44,999₹1,700₹595₹27,990₹599₹1,200₹34,990₹999₹1,299₹299₹1,500₹49,990₹931₹2,399₹399₹699₹1,099₹2,999₹1,099₹1,339₹12,999₹499₹2,100₹899₹599₹699₹65,000₹1,099₹20,900₹1,299₹399₹799₹1,999₹15,990₹1,499₹899₹1,600₹999₹499₹399₹849₹1,199₹1,299₹1,999₹22,990₹399₹2,499₹47,990₹399₹999₹1,999₹499₹299₹1,099₹199₹1,999₹499₹699₹999₹1,999₹1,200₹485₹1,999₹1,099₹18,990₹1,999₹11,000₹1,
# ...

# %%
total_discount_price=df['discounted_price'].sum()
print(total_discount_price)
# Out:
# ₹399₹199₹199₹329₹154₹149₹176.63₹229₹499₹199₹154₹299₹219₹350₹159₹349₹13,999₹249₹199₹13,490₹970₹279₹13,490₹59₹11,499₹199₹14,999₹299₹970₹299₹199₹179₹389₹599₹199₹99₹899₹199₹32,999₹970₹209₹19,999₹399₹999₹59₹333₹507₹309₹399₹199₹1,199₹179₹799₹6,999₹199₹230₹649₹15,999₹348₹154₹179₹32,990₹139₹329₹13,999₹309₹263₹7,999₹1,599₹219₹349₹349₹26,999₹115₹399₹199₹179₹10,901₹209₹1,434₹399₹139₹7,299₹299₹325₹29,999₹27,999₹30,990₹199₹649₹269₹24,999₹299₹199₹18,990₹290₹249₹345₹1,099₹719₹349₹849₹299₹21,999₹349₹399₹449₹299₹37,999₹99₹7,390₹273.10₹15,990₹399₹399₹210₹1,299₹347₹149₹228₹1,599₹1,499₹8,499₹20,990₹32,999₹799₹229₹9,999₹349₹489₹23,999₹399₹349₹179₹689₹30,990₹249₹999₹399₹349₹399₹1,699₹655₹749₹9,999₹195₹999₹499₹416₹368₹29,990₹339₹15,490₹499₹249₹399₹1,499₹9,490₹637₹399₹1,089₹339₹149₹149₹599₹299₹399₹339₹12,499₹249₹1,399₹32,999₹149₹325₹399₹199₹88₹399₹57.89₹799₹205₹299₹849₹949₹499₹299₹949₹379₹8,990₹486₹5,699₹709₹47,990₹299₹320₹139₹129₹24,999₹999₹225₹547₹259₹239₹349₹467₹449₹11,990₹350₹252₹204₹6,490₹235₹299₹799₹2
# ...

# %%
highest_rating_product=df[df['rating']==df['rating'].max()]
print(highest_rating_product)
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...           ₹2,099
#
#      actual_price discount_percentage rating rating_count  \
# 1279       ₹2,499                 16%      |          992
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# 1279  Decent product,doesn't pick up sand,Ok ok,Must...
#
#                                          review_content  \
# ...

# %%
product=df['product_id']
product_name=df['product_name']
amount=df['discounted_price']
product_sales=df.groupby('product_id')['discounted_price'].sum().reset_index()
product_sales=product_sales.sort_values(by='discounted_price',ascending=False)
plt.figure(figsize=(16,6))
plt.bar(product_sales['product_id'],product_sales['discounted_price'])
plt.xlabel('Product ID')
plt.ylabel('Total Sales')
plt.title('Total Sales by Product')
plt.xticks(rotation=90)
plt.show()

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce').fillna(0)
actual_price = df.groupby('actual_price')['rating'].sum()
plt.figure(figsize=(16,6))
plt.pie(product_rating.values, labels=product_rating.index, autopct='%1.1f%%')
plt.title('Total Rating by Product')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
actual_price = df['actual_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
discounted_price = df['discounted_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)

plt.scatter(actual_price,discounted_price)
plt.xlabel('Actual Price')
plt.ylabel('Discounted Price')
plt.title('Actual Price vs Discounted Price')
plt.show()
